# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Exploring the Dataset**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data exploration is the initial phase of data analysis where we aim to understand the data's characteristics, identify patterns, and uncover potential insights. It is a crucial step that helps us make informed decisions about subsequent analysis.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# -   Summarize the key characteristics of a dataset.
# -   Identify different data types commonly used in data analysis.

# %% [markdown]
# ### Install the required library

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\moham\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\moham\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\moham\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %% [markdown]
# ## Load the dataset

# %% [markdown]
# <h3>Read Data</h3>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
# Load the dataset: prefer remote, fall back to local file
remote_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
local_path = 'survey-data-with-duplicate.csv'
file_path = remote_path
import os
# try to use remote; if it fails later, pandas.read_csv will raise and we can fallback
# For offline execution, prefer the local file
if not os.path.exists(local_path):
    file_path = remote_path
else:
    file_path = local_path

# %% [markdown]
# Utilize the Pandas method read_csv() to load the data into a dataframe.

# %%
df = pd.read_csv(file_path)

# %% [markdown]
# # Hands on Lab

# %% [markdown]
# ## Explore the dataset

# %% [markdown]
# It is a good idea to print the top 5 rows of the dataset to get a feel of how the dataset will look.

# %% [markdown]
# Display the top 5 rows and columns from your dataset.

# %%
# Display the top 5 rows
print('Top 5 rows:' )
print(df.head())
# Out:
# Top 5 rows:
#                Age  Country Response
# 0  18-24 years old      USA      Yes
# 1  25-34 years old    India       No
# 2  35-44 years old   Canada      Yes
# 3  25-34 years old      USA      Yes
# 4  45-54 years old  Germany       No

# %% [markdown]
# ## Find out the number of rows and columns

# %% [markdown]
# Start by exploring the numbers of rows and columns of data in the dataset.

# %% [markdown]
# Print the number of rows in the dataset.

# %%
## Write your code here
# Run this in a new cell:
print(df.shape[0])
# OR
print(len(df))
# Out:
# 6
# 6

# %% [markdown]
# Print the number of columns in the dataset.

# %%
# Number of columns
print('Number of columns:', df.shape[1])
# Out:
# Number of columns: 3

# %% [markdown]
# ## Identify the data types of each column

# %% [markdown]
# Explore the dataset and identify the data types of each column.

# %% [markdown]
# Print the datatype of all columns.

# %%
# Print datatypes of each column
print(df.dtypes)
# Out:
# Age         str
# Country     str
# Response    str
# dtype: object

# %% [markdown]
# Print the mean age of the survey participants.

# %% [markdown]
# First let's map age ranges to approximate numeric values

# %%
age_mapping = {
    "Under 18 years old": 17,
    "18-24 years old": 21,
    "25-34 years old": 29,
    "35-44 years old": 39,
    "45-54 years old": 49,
    "55-64 years old": 59,
    "65 years or older": 70
}

# Create a new numeric Age column
df['Age_numeric'] = df['Age'].map(age_mapping)

# %%
# Calculate the mean age using the numeric mapping created earlier
print('Mean age (approx):', df['Age_numeric'].mean())
# Out:
# Mean age (approx): 31.333333333333332

# %% [markdown]
# The dataset is the result of a world wide survey. Print how many unique countries are there in the Country column.

# %%
# Number of unique countries
print('Unique countries:', df['Country'].nunique())
# Out:
# Unique countries: 4

# %% [markdown]
# Copyright ©  IBM Corporation. All rights reserved.
